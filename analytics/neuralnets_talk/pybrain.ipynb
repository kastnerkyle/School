# %% [markdown]
# sudo apt-get install python-pip
#
# pip install pybrain
#
# sudo pip install pybrain

# %% [markdown]
# http://stackoverflow.com/questions/12689293/event-sequences-recurrent-neural-networks-pybrain
#
# http://pybrain.org/docs/tutorial/netmodcon.html
#
# http://pybrain.org/docs/tutorial/fnn.html
#
# http://pybrain.org/docs/
#
# http://pybrain.org/docs/advanced/fast-pybrain.html
#
# https://github.com/bayerj/arac/wiki/installation

# %%
data = np.array([
[6, 6, 6, 6, 2, 6, 2, 6, 2, 2, 6, 2, 6, 6, 2, 6, 2, 4, 4, 4, 5, 6, 6, 1, 2, 2, 6, 6, 6, 2, 6, 2, 6, 6, 2, 6, 2, 2, 6, 2, 1, 2, 2, 6, 6, 6, 2, 1, 2, 6, 2, 6, 6, 2, 2, 6, 2, 2, 2, 6, 2, 6, 2, 2, 2, 2, 2, 6, 2, 2, 6, 6, 6, 6, 1, 2, 2, 6, 2, 2, 2, 2, 6, 2, 2, 2, 2, 3, 3, 2, 3, 2, 6, 6, 6, 6, 2, 6, 2, 6, 6, 2, 6, 2, 6, 6, 2, 6, 6, 2, 2, 3, 4, 3, 3, 1, 3, 1, 2, 1, 6, 1, 6, 6, 1, 6, 6, 2, 6, 2, 6, 2, 2, 2, 6, 6, 1, 6, 2, 6, 1, 2, 1, 6, 2, 6, 2, 2, 2, 2, 6, 6, 1, 6, 6, 2, 2, 6, 2, 2, 2, 3, 4, 4, 4, 6, 4, 6, 1, 6, 6, 1, 6, 6, 6, 6, 1, 6, 2, 2, 2, 6, 6, 6, 6, 2, 6, 6, 2, 2, 6, 2, 6, 2, 2, 2, 6, 2, 2, 2, 6, 6, 6, 6, 3, 2, 2, 6, 2, 2, 2, 2, 2, 2, 6, 2, 6, 2, 2, 2, 6, 2, 2, 6, 6, 2, 6, 6, 6, 2, 2, 2, 3, 3, 3, 4, 1, 6, 6, 1, 6, 6, 1, 6, 1, 6, 6, 6, 6, 1, 6, 6, 6, 2, 1, 2, 2, 2, 2, 2, 2, 3, 6, 6, 6, 6, 6, 2, 6],
[1, 6, 6, 1, 6, 1, 1, 1, 1, 1, 1, 6, 6, 6, 1, 2, 1, 6, 6, 1, 1, 1, 6, 6, 2, 1, 6, 6, 1, 1, 1, 6, 1, 2, 1, 6, 2, 2, 2, 2, 2, 6, 1, 6, 6, 1, 2, 1, 6, 6, 6, 1, 1, 1, 6, 6, 1, 1, 1, 1, 6, 1, 1, 2, 1, 6, 1, 6, 1, 1, 6, 2, 6, 2, 6, 6, 6, 3, 6, 6, 1, 6, 6, 2, 2, 2, 3, 2, 2, 6, 6, 6, 1, 1, 6, 2, 6, 6, 2, 6, 2, 6, 6, 1, 3, 6, 6, 1, 1, 1, 2, 2, 3, 2, 2, 6, 2, 2, 2, 1, 6, 1, 6, 1, 1, 6, 2, 1, 1, 1, 2, 2, 1, 6, 1, 1, 1, 1, 2, 6, 1, 1, 1, 1, 6, 1, 6, 1, 2, 1, 6, 1, 6, 6, 1, 6, 1, 2, 2, 2, 2, 3, 3, 2, 2, 2, 6, 6, 6, 6, 2, 1, 1, 6, 1, 1, 1, 6, 1, 6, 1, 6, 1, 6, 1, 1, 6, 6, 2, 1, 1, 6, 6, 1, 1, 2, 6, 2, 6, 6, 6, 1, 2, 6, 1, 6, 1, 1, 1, 1, 6, 1, 6, 1, 1, 6, 6, 1, 6, 6, 1, 6, 1, 6, 6, 1, 1, 6, 6, 2, 2, 2, 2, 2, 2, 2, 2, 2, 6, 6, 6, 6, 1, 6, 6, 6, 1, 6, 6, 1, 6, 6, 1, 1, 6, 1, 3, 3, 3, 5, 1, 6, 6, 6, 6, 6, 6, 6, 6],
[6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 6, 6, 2, 6, 6, 6, 2, 2, 6, 6, 6, 6, 6, 6, 6, 1, 6, 2, 6, 6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 1, 2, 6, 1, 6, 6, 1, 6, 2, 6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 6, 2, 6, 6, 1, 6, 6, 6, 6, 6, 6, 6, 3, 3, 6, 3, 2, 1, 2, 2, 1, 6, 6, 1, 6, 1, 6, 6, 6, 6, 6, 6, 1, 6, 6, 6, 1, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 6, 6, 6, 6, 6, 6, 2, 2, 6, 6, 2, 6, 1, 2, 6, 6, 6, 2, 6, 6, 2, 6, 6, 2, 6, 1, 6, 2, 6, 2, 1, 2, 6, 6, 2, 2, 6, 2, 6, 2, 2, 6, 2, 6, 6, 6, 2, 2, 2, 6, 6, 2, 6, 6, 2, 2, 6, 1, 2, 1, 2, 6, 6, 2, 2, 6, 6, 1, 2, 2, 1, 6, 2, 6, 2, 2, 1, 1, 5, 6, 3, 6, 1, 6, 6, 1, 2, 2, 6, 1, 6, 2, 6, 6, 1, 6, 2, 6, 2, 6, 6, 6, 1, 6, 1, 6, 6, 2, 2, 2, 1, 2, 3, 6, 1, 6, 1, 6, 1, 6, 1, 6, 6, 6, 1, 1, 6, 6, 6, 6, 6, 1, 6, 6, 6, 1, 6, 1, 1, 6, 6, 6, 6, 6, 6, 6, 6, 1, 6, 6, 1, 6],
[6, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 4, 3, 3, 6, 2, 6, 6, 6, 3, 4, 4, 3, 3, 3, 3, 3, 2, 6, 6, 3, 4, 4, 4, 4, 3, 4, 2, 6, 2, 2, 6, 2, 2, 6, 6, 3, 4, 5, 4, 4, 6, 3, 6, 6, 6, 2, 6, 2, 6, 6, 2, 2, 6, 4, 4, 5, 4, 3, 4, 3, 4, 4, 6, 2, 6, 6, 2, 2, 6, 2, 6, 6, 2, 6, 6, 2, 6, 6, 2, 6, 2, 6, 3, 5, 5, 5, 4, 4, 4, 3, 6, 2, 6, 6, 2, 6, 2, 6, 2, 2, 6, 2, 6, 6, 2, 6, 4, 4, 4, 4, 4, 4, 6, 3, 6, 6, 2, 6, 2, 6, 2, 6, 2, 6, 6, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 3, 5, 5, 4, 5, 3, 3, 3, 6, 2, 6, 6, 2, 2, 6, 2, 2, 2, 2, 6, 2, 3, 2, 2, 3, 6, 3, 2, 2, 3, 4, 4, 4, 4, 5, 5, 4, 4, 6, 6, 2, 6, 2, 6, 2, 2, 2, 2, 2, 2, 2, 5, 5, 4, 4, 5, 5, 2, 6, 2, 6, 6, 2, 6, 2, 6, 2, 2, 3, 3, 4, 4, 5, 4, 4, 4, 3, 4, 3, 6, 2, 6, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 4, 4, 4, 4, 5, 4, 4, 4, 3, 2, 2, 2, 6, 2, 2, 2, 6, 2, 6, 2, 6, 2, 2, 2, 2, 2, 3, 2],
[6, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 4, 3, 3, 6, 2, 6, 6, 2, 3, 4, 4, 3, 4, 4, 3, 3, 2, 2, 6, 3, 4, 4, 4, 4, 3, 4, 2, 3, 2, 2, 6, 3, 3, 6, 6, 3, 4, 5, 4, 5, 3, 3, 2, 6, 6, 2, 6, 2, 6, 6, 2, 2, 6, 4, 4, 4, 4, 4, 4, 5, 4, 4, 6, 2, 6, 6, 2, 2, 6, 2, 6, 6, 2, 6, 6, 2, 6, 6, 2, 6, 2, 6, 3, 4, 4, 4, 4, 4, 4, 4, 6, 2, 6, 6, 2, 6, 2, 6, 6, 6, 6, 2, 6, 2, 2, 6, 4, 4, 4, 4, 4, 4, 6, 3, 3, 6, 2, 2, 2, 6, 2, 6, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 6, 4, 5, 5, 5, 5, 2, 4, 6, 6, 2, 6, 6, 2, 2, 6, 2, 2, 2, 2, 6, 2, 3, 2, 2, 3, 6, 3, 2, 2, 3, 4, 4, 4, 4, 5, 5, 4, 3, 3, 6, 2, 6, 2, 2, 2, 6, 3, 2, 2, 2, 2, 5, 5, 4, 4, 4, 4, 3, 6, 2, 6, 6, 2, 6, 2, 6, 2, 2, 3, 3, 4, 4, 5, 4, 4, 4, 4, 4, 3, 6, 2, 6, 2, 2, 2, 6, 2, 2, 2, 2, 2, 2, 2, 3, 4, 4, 4, 4, 5, 4, 4, 4, 3, 2, 2, 2, 6, 6, 6, 2, 6, 2, 6, 2, 6, 2, 2, 2, 2, 2, 2, 2]])

# %%
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.datasets import SequentialDataSet
from pybrain.structure import SigmoidLayer
from pybrain.structure import LSTMLayer

import itertools
import numpy as np

data = data.T #Convert to 5 features, 269 values
print data

datain = data[:-1,:] 
dataout = data[1:,:] 

INPUTS = 5
OUTPUTS = 5
HIDDEN = 100

net = buildNetwork(INPUTS, HIDDEN, OUTPUTS, hiddenclass=LSTMLayer, 
                   outclass=SigmoidLayer, recurrent=True) 

ds = SequentialDataSet(INPUTS, OUTPUTS)

for x,y in itertools.izip(datain,dataout):
    ds.newSequence()
    ds.appendLinked(tuple(x), tuple(y))

net.randomize()

trainer = BackpropTrainer(net, ds)

err = []
for i in range(15):
    e = trainer.train()
    err.append(e)
    if (i % 10) == 0:
        print "Training error at epoch",i,":",e
# Out:
# [[6 1 6 6 6]
#  [6 6 6 2 2]
#  [6 6 6 2 2]
#  ...,
#  [6 6 6 2 2]
#  [2 6 1 3 2]
#  [6 6 6 2 2]]
# Training error at epoch
#  0 : 6.08654832247
# Training error at epoch
#  10 : 5.76763091411

# %%
plot(err, color="darkred")

# %%
#_ = [plot(data[:,i]) for i in range(5)]

#plot(data[:,3])
#print data.T.shape

_ = plot(data.T)

# %%
from pybrain.datasets            import ClassificationDataSet
from pybrain.utilities           import percentError
from pybrain.tools.shortcuts     import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules   import SoftmaxLayer
from pylab import ion, ioff, figure, draw, contourf, clf, show, hold, plot
from scipy import diag, arange, meshgrid, where
from numpy.random import multivariate_normal

means = [(-1,0),(2,4),(3,1)]
cov = [diag([1,1]), diag([0.5,1.2]), diag([1.5,0.7])]
alldata = ClassificationDataSet(2, 1, nb_classes=3)
for n in xrange(400):
    for klass in range(3):
        input = multivariate_normal(means[klass],cov[klass])
        alldata.addSample(input, [klass])

tstdata, trndata = alldata.splitWithProportion( 0.25 )
trndata._convertToOneOfMany( )
tstdata._convertToOneOfMany( )
print "Number of training patterns: ", len(trndata)
print "Input and output dimensions: ", trndata.indim, trndata.outdim
print "First sample (input, target, class):"
print trndata['input'][0], trndata['target'][0], trndata['class'][0]
# Out:
# Number of training patterns:  900
# Input and output dimensions:  2 3
# First sample (input, target, class):
# [-0.70149941  1.51014169] [1 0 0] [ 0.]

# %%
ticks = arange(-3.,6.,0.2)
X, Y = meshgrid(ticks, ticks)
# need column vectors in dataset, not arrays
griddata = ClassificationDataSet(2,1, nb_classes=3)
for i in xrange(X.size):
    griddata.addSample([X.ravel()[i],Y.ravel()[i]], [0])
griddata._convertToOneOfMany()  # this is still needed to make the fnn feel comfy

fnn = buildNetwork( trndata.indim, 5, trndata.outdim, outclass=SoftmaxLayer )
trainer = BackpropTrainer( fnn, dataset=trndata, momentum=0.1, verbose=True, weightdecay=0.01)

# %%
for i in range(20):
    trainer.trainEpochs( 1 )
    trnresult = percentError( trainer.testOnClassData(),
                              trndata['class'] )
    tstresult = percentError( trainer.testOnClassData(
           dataset=tstdata ), tstdata['class'] )

    print "epoch: %4d" % trainer.totalepochs, \
          "  train error: %5.2f%%" % trnresult, \
          "  test error: %5.2f%%" % tstresult
    
    out = fnn.activateOnDataset(griddata)
    out = out.argmax(axis=1)  # the highest output activation gives the class
    out = out.reshape(X.shape)
    
    figure(1)
    ioff()  # interactive graphics off
    clf()   # clear the plot
    hold(True) # overplot on
    for c in [0,1,2]:
        here, _ = where(tstdata['class']==c)
        plot(tstdata['input'][here,0],tstdata['input'][here,1],'o')
    if out.max()!=out.min():  # safety check against flat field
        contourf(X, Y, out)   # plot the contour
    ion()   # interactive graphics on
    draw()  # update the plot
    ioff()
    show()
# Out:
# Total error: 0.0161406421225
# epoch:   70
#    train error:  5.78%   test error:  6.00%
# Total error: 0.0159935030513
# epoch:   71
#    train error:  5.56%   test error:  6.00%
# Total error: 0.0161116362023
# epoch:   72
#    train error:  5.22%   test error:  6.00%
# Total error: 0.0161212166615
# epoch:   73
#    train error:  5.67%   test error:  6.00%
# Total error: 0.016061770823
# epoch:   74
#    train error:  6.33%   test error:  6.67%
# Total error: 0.0161804215783
# epoch:   75
#    train error:  5.67%   test error:  5.67%
# Total error: 0.016068551854
# epoch:   76
#    train error:  5.33%   test error:  5.33%
# Total error: 0.0160854806575
# epoch:   77
#    train error:  5.00%   test error:  5.67%
# Total error: 0.016104682751
# epoch:   78
#    train error:  5.44%   test error:  5.67%
# Total error: 0.0161436950461
# epoch:   79
#    train error:  5.33%   test error:  6.00%
# Total error: 0.0160937727804
# epoch:   80
#    train error:  5.22%   test error:  5.33%
# Total error: 0.0161664870994
# epoch:   81
#    train error:  5.33%   test error:  6.00%
# Total error: 0.0718702059437
# epoch:    1
#    train error:  6.44%   test error:  7.00%
# Total error: 0.0384084311233
# epoch:    2
#    train error:  6.33%   test error:  4.67%
# Total error: 0.0271809865041
# epoch:    3
#    train error:  6.22%   test error:  5.00%
# Total error: 0.0221902493835
# epoch:    4
#    train error:  6.00%   test error:  4.00%
# Total error: 0.0199411330665
# epoch:    5
#    train error:  6.22%   test error:  4.33%
# Total error: 0.0187418539287
# epoch:    6
#    train error:  6.33%   test error:  4.67%
# Total error: 0.0180252848335
# epoch:    7
#    train error:  5.89%   test error:  5.00%
# Total error: 0.0179624449321
# epoch:    8
#    train error:  6.33%   test error:  4.67%
# Total error: 0.0175686723585
# epoch:    9
#    train error:  6.22%   test error:  4.67%
# Total error: 0.0173947894596
# epoch:   10
#    train error:  6.22%   test error:  4.67%
# Total error: 0.0171529760205
# epoch:   11
#    train error:  6.00%   test error:  5.67%
# Total error: 0.0171085096671
# epoch:   12
#    train error:  6.11%   test error:  4.67%
# Total error: 0.0170777782839
# epoch:   13
#    train error:  6.11%   test error:  4.67%
# Total error: 0.0170474506538
# epoch:   14
#    train error:  6.11%   test error:  4.33%
# Total error: 0.0168866310916
# epoch:   15
#    train error:  5.78%   test error:  4.67%
# Total error: 0.0169135210844
# epoch:   16
#    train error:  5.89%   test error:  4.67%
# Total error: 0.016894631135
# epoch:   17
#    train error:  5.89%   test error:  5.00%
# Total error: 0.0166543793404
# epoch:   18
#    train error:  5.78%   test error:  6.00%
# Total error: 0.0166909568241
# epoch:   19
#    train error:  5.67%   test error:  6.33%
# Total error: 0.0166607534679
# epoch:   20
#    train error:  6.00%   test error:  4.33%
